# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/124_function_definition_125_parameters_and_factors_of_a_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 124 함수 정의 : def

# %%
def fune():       # fune은 사용자가 정의하는 함수 이름
  코드
  return
# 함수 호출 방법
fune()

# %%
def fune(매개변수1, 매개변수2, ...):
  코드
  return
# 함수 호출 방법
fune(인자1, 인자2, ...)

# %%
def fune():
  코드
  return 리턴값
# 함수 호출 방법
<리턴값을 받을 변수 = fune()

# %%
def fune(매개변수1, 매개변수2, ...):
  코드
  return 리턴값
# 함수 호출 방법
<리턴값을 받을 변수 = fune(인자1, 인자2, ...)

# %%
def displayFilepath():
  filepath = 'c:/myworks/pythonstrudy.py'
  print(f'파일경로: {filepath}')
  return

displayFilepath()
# Out:
# 파일경로: c:/myworks/pythonstrudy.py

# %%
def printFilepath(folder, filename):
  print(f'파일경로: {folder+filename}')
  return

printFilepath('c:/myworks/', 'pythonstrudy.py')
# Out:
# 파일경로: c:/myworks/pythonstrudy.py

# %%
def getFilepath():
  filepath = 'c:/myworks/pythonstrudy.py'
  return filepath

filepath = makeFilepath()
print(f'파일경로: {filepath}')

# %%
def makeFilepath(folder, filename):
  return folder + filename

filepath = makeFilepath('c:/myworks/', 'pythonstrudy.py')
print(f'파일경로: {filepath}')
# Out:
# 파일경로: c:/myworks/pythonstrudy.py

# %% [markdown]
# # 125 함수의 매개변수와 인자

# %%
def setLevel(character, level=1):
  print(f'{character}의 레벨: {level}')
  return

# %%
setLevel('유비')
setLevel('제갈량', 10)

# %%
def setLevel(level=1, character):
# Out:
#   File "/tmp/ipython-input-3423944849.py", line 1
#     def setLevel(level=1, character):
#                           ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def setLevel(character, level):
  print(f'{character}의 레벨: {level}')
  return

# %%
setLevel(level=5, character='장비')
# Out:
# 장비의 레벨: 5

# %%
def setLevel(*args):
  print(args)
  return

# %%
setLevel('관우', 7)
setLevel('조운', 'named', 10)
# Out:
# ('관우', 7)
# ('조운', 'named', 10)

# %%
def setLevel(**kwargs):
  print(kwargs)
  return

# %%
setLevel(character='조운', level=10)
setLevel(character='황충', category='named', level=5)
# Out:
# {'character': '조운', 'level': 10}
# {'character': '황충', 'category': 'named', 'level': 5}

# %%
def setLevel(character, level, *args):
  print(f'장수: {character}, 레벨: {level}')
  if len(args) != 0:
    print(f'기타 특성: {args}')
  return

# %%
setLevel('조조', 3)
# Out:
# 장수: 조조, 레벨: 3

# %%
setLevel('유비', 3, 'named', 'leader')
# Out:
# 장수: 유비, 레벨: 3
# 기타 특성: ('named', 'leader')

# %%
def setLevel(character, level, **kwargs):
  print(f'장수: {character}, 레벨: {level}')
  if len(kwargs) != 0:
    for k, v in kwargs.items():
      print(f'{k}: {v}')
  return

# %%
setLevel('조조', 3)
# Out:
# 장수: 조조, 레벨: 3

# %%
setLevel('유비', 3, category='named', position='leader')
# Out:
# 장수: 유비, 레벨: 3
# category: named
# position: leader
