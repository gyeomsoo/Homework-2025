# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/166_Check_whether_it_is_a_file_or_a_directory_167_Handling_JSON_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 166 파일인지 디렉토리인지 체크 : os.path.isfile (), os.path.isdir ()

# %%
from os import listdir
from os.path import isdir

fileList = [ ]
dirList = [ ]
files = listdir('./')               # 현재 작업 디렉토리의 파일 리스트
for file in files:
    if isdir(file):
        dirList.append(f'<DIR> {file}')
    else:
        fileList.append(file)

fileList.sort()
dirList.sort()

for d in dirList:
  print(d)

for f in fileList:
  print(f)

# %% [markdown]
# # 167 JSON 파일 다루기

# %%
import json
with open('package.json') as f:
  data = json.load(f)
print(data)

# %%
profile = {'name':'조조', 'age':45, 'nationality':'위나라',
           'skill':['집착', '배신'], 'alive':True}
with open('profile.json', 'w') as f:
  json.dump(profile, f, indent=4)

# %%
with open('profile.json') as f:
  data = json.load(f)
print(data)

# %%
with open('prifile.json', 'w') as f:
  json.dump(profile, f, indent=4, ensure_ascii=False)
