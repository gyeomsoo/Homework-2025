# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/138_exceptional_handling_139_exceptional_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 138 예외처리 2 : try ~ except ~ else

# %%
try:
  잠재적으로 오류 및 예외가 발생할 수 있는 코드
except:
  예외가 발생했을 때 예외를 처리하는 코드
else:
  <try ~ except>로 감싸진 코드에서 예외가 발생하지 않았을 때 수행되는 코드

# %%
fileList = ['file01.jpg', 'file02.jpg', 'file03', 'file04.jpg']
try:
  for file in fileList:
    fname = file.split('.')                     # 파일 이름과 파일 확장자 분리
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 오류 발생!')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# ERROR!! <file03> 처리중 오류 발생!

# %%
fileList = ['file01.jpg', 'file02.jpg', 'file03.jpg', 'file04.jpg']
try:
  for file in fileList:
    fname = file.split('.')                     # 파일 이름과 파일 확장자 분리
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 오류 발생!')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# 파일 이름: file03, 파일확장자: jpg
# 파일 이름: file04, 파일확장자: jpg
# 모든 파일을 성공적으로 처리했습니다.

# %% [markdown]
# # 139 예외처리 3 : try ~ except ~ finally

# %%
try:
  잠재적으로 오류 및 예외가 발생할 수 있는 코드
except:
  예외가 발생했을 때 예외를 처리하는 코드
finally:
  무조건 수행되는 코드

# %%
fileList = ['file01.jpg', 'file02.jpg', 'file03', 'file04.jpg']
try:
  for file in fileList:
    fname = file.split('.')                     # 파일 이름과 파일 확장자 분리
    print(f'파일 이름: {fname[0]}, 파일확장자: {fname[1]}')
except:
  print(f'ERROR!! <{file}> 처리중 오류 발생!')
else:
  print('모든 파일을 성공적으로 처리했습니다.')
finally:
  print('무조건 수행되는 코드!')
# Out:
# 파일 이름: file01, 파일확장자: jpg
# 파일 이름: file02, 파일확장자: jpg
# ERROR!! <file03> 처리중 오류 발생!
# 무조건 수행되는 코드!
