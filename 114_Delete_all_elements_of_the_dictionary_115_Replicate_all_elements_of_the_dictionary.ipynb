# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/114_Delete_all_elements_of_the_dictionary_115_Replicate_all_elements_of_the_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 114 딕셔너리의 모든 요소 삭제 : *d*.clear ()

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
greats.clear()
print(greats)
# Out:
# {}

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
del greats
print(greats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-323071278.py in <cell line: 0>()
#       1 greats = {'유비':89, '관우':95, '장비':91, '조운':94}
#       2 del greats
# ----> 3 print(greats)
#
# NameError: name 'greats' is not defined

# %% [markdown]
# # 115 딕셔너리의 모든 요소 복제 : *d*.copy()

# %%
greats = {'유비':89, '관우':95, '장비':91, '조운':94}
buffer = greats.copy()
del buffer['관우']
print(f'greats: {greats}')
print(f'buffer: {buffer}')
# Out:
# greats: {'유비': 89, '관우': 95, '장비': 91, '조운': 94}
# buffer: {'유비': 89, '장비': 91, '조운': 94}
