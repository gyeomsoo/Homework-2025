# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/150_Open_and_close_files_151_Open_and_close_files_automatically.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 150 파일 열고 닫기 : *f*.open(), *f*.close()

# %%
파일 객체 = open(파일 경로, 모드, encoding = 인코딩 방식)

# %%
파일 객체 = open(파일 경로)     # 텍스트 읽기 모드로 파일을 오픈

# %%
파일 객체.close()

# %%
# 텍스트 파일을 'CP949' 인코딩으로 읽거나 쓰기
f = opem('myfile.txt', encoding = 'CP949')
<파일 처리 코드>
f.close()

# 바이너리 이미지 파일 읽기
f = opem('image.fpg', 'rb')
<파일 처리 코드>
f.close()

# %% [markdown]
# # 151 파일을 열고 자동으로 닫기 : with open() as *f*

# %%
with open(파일 경로, 모드, encoding = 인코딩 방식) as 파일 객체:
  <파일 처리 코드>

# %%
f = open('myfile.txt', 'r')
readData = f.readlines()
f.close()

# %%
with open('myfile.txt', 'r') as f:
  readData = f.readlines()
