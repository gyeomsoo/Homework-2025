# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/142_Making_an_exception_143_Making_an_exception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 142 예외 발생시키기 1 : assert

# %%
assert 조건, 예외 메시지

# %%
if __debug__:
  if not 조건: raise AssertionError(예외 메시지)

# %%
> python -0 pythontest.py

# %%
data = ['a', 'bc', 1234, 'def', 'ghij']
try:
  for d in data:
    assert type(d) is str, f'문자열이 아닌 데이터 <{d}> 있음!'
    print(d)
except AssertionError as e:
  print(e)
# Out:
# a
# bc
# 문자열이 아닌 데이터 <1234> 있음!

# %% [markdown]
# # 143 예외 발생시키기 2 : raise

# %%
raise 예외클래스('프로그래머가 지정한 예외 메시지')

# %%
def makeException():
  raise RuntimeError('뭔가 잘못되었음')

# %%
try:
  makeException()
except Exception as e:
  print(e)
# Out:
# 뭔가 잘못되었음

# %%
try:
  makeException()
except Exception as e:
  print(e)
  raise
# Out:
# 뭔가 잘못되었음
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2653565888.py in <cell line: 0>()
#       1 try:
# ----> 2   makeException()
#       3 except Exception as e:
#       4   print(e)
#       5   raise
#
# /tmp/ipython-input-3340200797.py in makeException()
#       1 def makeException():
# ----> 2   raise RuntimeError('뭔가 잘못되었음')
#
# RuntimeError: 뭔가 잘못되었음

# %%
try:
  makeException()
except Exception as e:
  raise VlaueError('값이 잘못된 것 같음')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3221645116.py in <cell line: 0>()
#       1 try:
# ----> 2   makeException()
#       3 except Exception as e:
#
# /tmp/ipython-input-3340200797.py in makeException()
#       1 def makeException():
# ----> 2   raise RuntimeError('뭔가 잘못되었음')
#
# RuntimeError: 뭔가 잘못되었음
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3221645116.py in <cell line: 0>()
#       2   makeException()
#       3 except Exception as e:
# ----> 4   raise VlaueError('값이 잘못된 것 같음')
#
# NameError: name 'VlaueError' is not defined
