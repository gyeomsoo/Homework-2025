# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/152_Read_File_153_Write_a_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 152 파일 읽기 : *f*.read()

# %%
with open('prophet_en.txt', 'r') as f:
  readData = f.read()
print(readData)

# %%
with open('prophet_ko.txt', 'r') as f:
  readData = f.read()
print(readData)

# %%
with open('prophet_cp949_ko.txt', 'r') as f:
  readData = f.read()
print(readData)

# %%
with open('prophet_cp949_ko.txt', 'r', encoding='cp949') as f:

# %%
with open('sunrise.jpg', 'rb') as f:
  readData = f.read(50)
print(readData.hex('-'))

# %% [markdown]
# # 153 파일 쓰기 : *f*.write()

# %%
data = input('저장할 문장을 입력하세요: ')
flag = input('입력한 문장을 저장하시겠습니까? (Y/N)')
if flag.lower() == 'y':
  with open('mydata.txt', 'w') as f:
    f.write(data)
  print('입력한 문장을 "mydata.txt"에 저장했습니다.')
else:
  print('입력한 문장을 저장하지 않습니다.')
# Out:
# 저장할 문장을 입력하세요: 많은 일들이 일어나고 있습니다
# 입력한 문장을 저장하시겠습니까? (Y/N)y
# 입력한 문장을 "mydata.txt"에 저장했습니다.

# %%
data = b'A lot of things occur each day'
with open('mydata.bin', 'wb') as f:
  f.write(data)

# %%
with open('mydata.bin', 'rb') as f:
  data = f.read()
print(data)
# Out:
# b'A lot of things occur each day'
