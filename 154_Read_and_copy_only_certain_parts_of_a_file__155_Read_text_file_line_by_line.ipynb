# %% [markdown]
# <a href="https://colab.research.google.com/github/gyeomsoo/Homework-2025/blob/main/154_Read_and_copy_only_certain_parts_of_a_file__155_Read_text_file_line_by_line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 154 파일의 특정 부분만 읽고 복사 : *f*.seek()

# %%
with open('prophet_en.txt', 'r') as f:
  f.seek(335)           # 파일포인터를 335바이트 위치로 이동
  data = f.read()
print(data)

# %% [markdown]
# # 155 텍스트 파일 한 라인씩 읽기 : *f*.readline(), *f*.readlines()

# %%
with open('prophet_en.txt', 'r') as f:
  data = f.readline()
  while line != '':
    print(f'>> {line[:-1]}')
    k = input('다음 줄: 엔터 입력. 종료: /q 입력: ')
    if k == '/q':
      break
    line = f.readline()

# %%
with open('prophet_en.txt', 'r') as f:
  lines = f.readlines()
  for line in lines:
    print(f'>> {line[:-1]}')
    k = input('다음 줄: 엔터 입력. 종료: /q 입력: ')
    if k == '/q':
      break
